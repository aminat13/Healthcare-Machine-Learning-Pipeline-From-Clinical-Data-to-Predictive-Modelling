# %%
import pandas as pd

proxy_df = pd.DataFrame(columns=["patient_ID", "ICD_10", "Age", "ATC"])

age_check = (proxy_df["Age"] >= 40) & (data00["Age"] <=80)
icd_10_check = proxy_df["ICD_10"].str.startswith("G30")
atc_check = proxy_df["ATC"].str.startswith("NO6D")
other_check = proxy_df["ICD_10"].str.startswith("F01", "F02", "F03")

Data00 = data00[age_check & icd_10_check & atc_check & ~other_check]
